# %% [markdown]
# * [Question 9](#9)

# %%
import pandas as pd
import requests

# %%
out = requests.get(
    'https://www.statlearning.com/s/College.csv',
    headers={
        'accept': 'application/json'
    },
    verify=False
)
with open(out.headers['Content-Disposition'].rsplit('filename=')[-1].split(';')[0].replace('"',''), 'wb') as f:
    f.write(out.content)
# Out:
# /Users/leo/.conda/envs/islp/lib/python3.11/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.statlearning.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/leo/.conda/envs/islp/lib/python3.11/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'static1.squarespace.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
college = pd.read_csv('College.csv')
college.columns
# Out:
# Index(['Unnamed: 0', 'Private', 'Apps', 'Accept', 'Enroll', 'Top10perc',
#        'Top25perc', 'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board',
#        'Books', 'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni',
#        'Expend', 'Grad.Rate'],
#       dtype='object')

# %%
college = college.rename({'Unnamed: 0' : 'College'}, axis=1)
college = college.set_index("College")

# %%
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
# 8 (c)
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# # 8(d)

# %%
pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']], figsize=(12,8))
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
# an individual plot
college.plot(x='Apps', y='Enroll', kind='scatter')
# Out:
# <Axes: xlabel='Apps', ylabel='Enroll'>

# %% [markdown]
# ## 8 (e)

# %%
college.boxplot(column='Outstate', by='Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# ## 8 (f)
# there's an error in the bins edges given in the book. they are given as fractions but should be percentages

# %%
college['Elite'] = pd.cut(college['Top10perc'], [0, 50, 100], labels=['No', 'Yes'])

# %%
college.Elite.value_counts()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %%
college.boxplot(column='Outstate', by='Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# ## 8 (g)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,10))
plt.subplot(2, 2, 1)
college['Top10perc'].plot.hist(bins=5)
plt.xlabel('Top10perc')
plt.subplot(2, 2, 2)
college['Top10perc'].plot.hist() # default 10 bins
plt.xlabel('Top10perc')
plt.subplot(2, 2, 3)
college['F.Undergrad'].plot.hist() 
plt.xlabel('F.Undergrad')
plt.subplot(2, 2, 4)
college['PhD'].plot.hist() 
plt.xlabel('PhD')
# Out:
# Text(0.5, 0, 'PhD')

# %% [markdown]
# ## 9

# %%
out = requests.get(
    'https://www.statlearning.com/s/Auto.csv',
    headers={
        'accept': 'application/json'
    },
    verify=False
)
with open(out.headers['Content-Disposition'].rsplit('filename=')[-1].split(';')[0].replace('"',''), 'wb') as f:
    f.write(out.content)
# Out:
# /Users/leo/.conda/envs/islp/lib/python3.11/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.statlearning.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/leo/.conda/envs/islp/lib/python3.11/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'static1.squarespace.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
auto = pd.read_csv('Auto.csv')
print(auto.shape)
auto.notnull().sum(axis=0) # there's no nulls in raw data
# Out:
# (397, 9)
# mpg             397
# cylinders       397
# displacement    397
# horsepower      397
# weight          397
# acceleration    397
# year            397
# origin          397
# name            397
# dtype: int64

# %%
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
print(auto.cylinders.value_counts())
auto.origin.value_counts() # only qualitative variable as far as I can tell
# Out:
# 4    203
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64
# 1    248
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
# 9(b) and (c)
auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# 9(d)
auto_short = pd.concat([auto.loc[0:8,:], auto.loc[84:,:]])
auto_short.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  322.000000  322.000000    322.000000   322.000000    322.000000
# mean    24.446584    5.366460    186.770186  2931.372671     15.725466
# std      7.897147    1.652674     99.606562   810.712477      2.676686
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000     98.500000  2211.250000     14.000000
# 50%     23.950000    4.000000    144.500000  2792.500000     15.550000
# 75%     30.650000    6.000000    250.000000  3494.250000     17.275000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000
#
#              year      origin
# count  322.000000  322.000000
# mean    77.136646    1.602484
# std      3.119623    0.818627
# min     70.000000    1.000000
# 25%     75.000000    1.000000
# 50%     77.000000    1.000000
# 75%     80.000000    2.000000
# max     82.000000    3.000000

# %%
# 9(e)
pd.plotting.scatter_matrix(auto[[x for x in auto.columns if x not in ['name', 'origin']]], figsize=(16,16))
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='cylinders', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>,
#         <Axes: xlabel='acceleration', ylabel='mpg'>,
#         <Axes: xlabel='year', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='cylinders'>,
#         <Axes: xlabel='cylinders', ylabel='cylinders'>,
#         <Axes: xlabel='displacement', ylabel='cylinders'>,
#         <Axes: xlabel='weight', ylabel='cylinders'>,
#         <Axes: xlabel='acceleration', ylabel='cylinders'>,
#         <Axes: xlabel='year', ylabel='cylinders'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='cylinders', ylabel='displacement'>,
#         <Axes: xlabel='displacement', ylabel='displacement'>,
#         <Axes: xlabel='weight', ylabel='displacement'>,
#         <Axes: xlabel='acceleration', ylabel='displacement'>,
# ...

# %% [markdown]
# seems all the quantitative variables are predictive (what's displacement though?).
#
# if displacement is range, then it should be positively correlated, but is the opposite.
#
# let's check the quantitative one:

# %%
auto.boxplot(column='mpg', by='origin') # predictive as well!
# Out:
# <Axes: title={'center': 'mpg'}, xlabel='origin'>

# %% [markdown]
# ## 10

# %%
from ISLP import load_data
boston = load_data('Boston')

# %%
print(boston.shape)
boston.head()
# Out:
# (506, 13)
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
# 10(c)
pd.plotting.scatter_matrix(boston[[x for x in boston.columns if x not in ['chas']]], figsize=(16,16));

# %% [markdown]
# ## 10(d)
# It looks like `lstat` (lower status of the population (percent))  and `medv` (median value of owner-occupied homes in $1000s) are predictive of crime rate. home value seems like an obvious guess, unless you include white-collar crime statistics 😂

# %%
figure, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(12,5))
ax1.scatter(boston['lstat'], boston['crim'])
plt.xlabel('lstat')
ax2.scatter(boston['medv'], boston['crim'])
plt.xlabel('medv');

# %%
# 10(e)
boston.crim.hist(bins=40) # Jesus!
# Out:
# <Axes: >

# %%
boston.ptratio.hist()
# Out:
# <Axes: >

# %%
boston.tax.hist()
# Out:
# <Axes: >

# %%
# 10(f)
boston.chas.value_counts()
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64

# %%
# 10(h) suburb names are not given
boston[boston.medv == boston.medv.min()]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
# 10(i)
boston[boston.rm > 7].shape
# Out:
# (64, 13)

# %%
boston[boston.rm > 8].shape
# Out:
# (13, 13)

# %%
boston[boston.rm > 8].describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...

# %% [markdown]
# low criminality, high tax, ...
